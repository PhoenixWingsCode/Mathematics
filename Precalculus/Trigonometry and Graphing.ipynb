# %% [markdown]
# # Section 1 : Graphing trig functions

# %%
import matplotlib.pyplot as plt
from IPython import display
import math
import time

fig, ax = plt.subplots()
plt.axis([-2, 2, -2, 2])
ax.set_aspect('equal')

for a in range(360):
    x = math.cos(math.radians(a))
    y = math.sin(math.radians(a))
    plt.plot([x], [y], 'ro')

plt.show()

# %% [markdown]
# # Section 2 : Graph of sine in degrees

# %%
import matplotlib.pyplot as plt
from IPython import display
import math

fig, ax = plt.subplots()
plt.axis([0, 360, -360, 360]) # x -> positive, negative, y-> negative, positive

for a in range(360):
    x = a
    y = math.sin(math.radians(a))
    plt.plot([x], [y], 'ro')

plt.show()

# %%
import matplotlib.pyplot as plt
from IPython import display
import math

fig, ax = plt.subplots()
plt.axis([0, 360, -2, 2]) # x -> positive, negative, y-> negative, positive

for a in range(360):
    x = a
    y = math.sin(math.radians(a))
    plt.plot([x], [y], 'ro')

plt.show()

# %% [markdown]
# # Section 3 : Circle using radians

# %%
import matplotlib.pyplot as plt
from IPython import display
import math

fig, ax = plt.subplots()
plt.axis([-2, 2, -2, 2])
ax.set_aspect('equal') 

for a in range(70):
    angle = 0.1*a
    x = math.cos(angle)
    y = math.sin(angle)
    plt.plot([x], [y], 'ro')

plt.show()

# %% [markdown]
# # Section 4 : Graph of sine in radians

# %%
import matplotlib.pyplot as plt
from IPython import display
import math

fig, ax = plt.subplots()
plt.axis([0, 7, -2, 2])

for a in range(70):
    angle = 0.1*a
    x = angle
    y = math.sin(angle)
    plt.plot([x], [y], 'ro')

plt.show()

# %% [markdown]
# # Section 5 : Graph of sine using numpy

# %%
import matplotlib.pyplot as plt
from IPython import display
import numpy as np
import math

# Graph dimensions
xmin = -2
xmax = 7
ymin = -2
ymax = 2
points = 4*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], 'b')
plt.plot([0,0], [ymin, ymax], 'b')

y = np.sin(x)
#y = np.cos(x)
plt.plot(x, y, 'r')

plt.show()

# %%
#Smoothing

import matplotlib.pyplot as plt
from IPython import display
import numpy as np
import math

# Graph dimensions
xmin = -2
xmax = 7
ymin = -2
ymax = 2
points = 5*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], 'b')
plt.plot([0,0], [ymin, ymax], 'b')

y = np.sin(x)
#y = np.cos(x)
plt.plot(x, y, 'r')

plt.show()

# %%
# Really Smoothing

import matplotlib.pyplot as plt
from IPython import display
import numpy as np
import math

# Graph dimensions
xmin = -2
xmax = 7
ymin = -2
ymax = 2
points = 10*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], 'b')
plt.plot([0,0], [ymin, ymax], 'b')

y = np.sin(x)
#y = np.cos(x)
plt.plot(x, y, 'r')

plt.show()

# %%
# Cosine

import matplotlib.pyplot as plt
from IPython import display
import numpy as np
import math

# Graph dimensions
xmin = -2
xmax = 7
ymin = -2
ymax = 2
points = 10*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], 'b')
plt.plot([0,0], [ymin, ymax], 'b')

#y = np.sin(x)
y = np.cos(x)
plt.plot(x, y, 'r')

plt.show()
