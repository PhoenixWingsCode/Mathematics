# %% [markdown]
# # Section 1 : Graph of tangents and more

# %%
import matplotlib.pyplot as plt
from IPython import display
import numpy as np
import math

# Graph dimensions
xmin = -2
xmax = 14
ymin = -2
ymax = 2
points = 5*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], 'b')
plt.plot([0, 0], [ymin, ymax], 'b')

#Tangent
y = np.tan(x)
y[:-1][np.diff(y) < 0] = np.nan #Lesser than zero than nan

plt.plot(x, y, 'r')
plt.show()

# %% [markdown]
# # Section 2 : Cotangent

# %%
import matplotlib.pyplot as plt
from IPython import display
import numpy as np
import math

# Graph dimensions
xmin = -2
xmax = 14
ymin = -2
ymax = 2
points = 5*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], 'b')
plt.plot([0, 0], [ymin, ymax], 'b')

#Tangent
y = 1/np.tan(x)
y[:-1][np.diff(y) > 0] = np.nan #Greater than zero than nan

plt.plot(x, y, 'r')
plt.show()

# %% [markdown]
# # Section 3 : Secant

# %%
import matplotlib.pyplot as plt
from IPython import display
import numpy as np
import math

# Graph dimensions
xmin = -2
xmax = 14
ymin = -2
ymax = 2
points = 5*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], 'b')
plt.plot([0, 0], [ymin, ymax], 'b')

#Secant
y = 1/np.cos(x)
y[:-1][np.diff(y) > 2] = np.nan

plt.plot(x, y, 'r')
plt.show()

# %% [markdown]
# # Section 4 : Cosine

# %%
import matplotlib.pyplot as plt
from IPython import display
import numpy as np
import math

# Graph dimensions
xmin = -2
xmax = 14
ymin = -2
ymax = 2
points = 5*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], 'b')
plt.plot([0, 0], [ymin, ymax], 'b')

#Cosine
y = 1/np.cos(x)
y[:-1][np.diff(y) > 2] = np.nan
y2 = np.cos(x) 

plt.plot(x, y, 'r')
plt.plot(x, y2, 'g')
plt.show()

# %% [markdown]
# # Section 5 : Cosecant

# %%
import matplotlib.pyplot as plt
from IPython import display
import numpy as np
import math

# Graph dimensions
xmin = -2
xmax = 14
ymin = -2
ymax = 2
points = 5*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], 'b')
plt.plot([0, 0], [ymin, ymax], 'b')

#Cosecant
y = 1/np.sin(x)
#y[:-1][np.diff(y) > 2] = np.nan

plt.plot(x, y, 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
from IPython import display
import numpy as np
import math

# Graph dimensions
xmin = -2
xmax = 14
ymin = -2
ymax = 2
points = 5*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], 'b')
plt.plot([0, 0], [ymin, ymax], 'b')

#Cosecant
y = 1/np.sin(x)
y[:-1][np.diff(y) > 2] = np.nan

plt.plot(x, y, 'r')
plt.show()

# %% [markdown]
# # Section 6 : Sine

# %%
import matplotlib.pyplot as plt
from IPython import display
import numpy as np
import math

# Graph dimensions
xmin = -2
xmax = 14
ymin = -2
ymax = 2
points = 5*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0, 0], 'b')
plt.plot([0, 0], [ymin, ymax], 'b')

#Sine
y = 1/np.sin(x)
y[:-1][np.diff(y) > 2] = np.nan
y2 = np.sin(x) 

plt.plot(x, y, 'r')
plt.plot(x, y2, 'g')
plt.show()
