# %% [markdown]
# # Section 1 : Limits - Hole in the graph
#
# y = 3(x-2)/(x-2)

# %%
x = 2
h = 0.00001 # h is that little more or less difference

yRight = (3 * ((x + h) - 2)) / ((x + h) - 2) # going to right side so increasing
yLeft = (3 * ((x - h) - 2)) / ((x - h) - 2) # going to right side so decreasing

print("y right = ", yRight)
print("y left = ", yLeft)

if round(yRight) != round(yLeft):
    print("Limit does not exist at x = ", x)
# Out:
# y right =  3.0
# y left =  3.0

# %% [markdown]
# # Section 2 : Limits - where is the function undefined?  (Asymptotes)
#
# Example function : y = 3*x**2/x**2 - 4

# %%
import sympy
from sympy import *
from sympy.solvers import solve

x = symbols('x')

# Put the equation here
eq = x**2 - 4

# solve() sets the equation equal to zero
print("x = ", solve(eq, x))
# Out:
# x =  [-2, 2]

# %% [markdown]
# # Section 3 : Limits - approaching from right to left
#
# Example function : y = 3*x**2/x**2 - 4

# %%
x = 2
h = 0.0001

yRight = (3 * (x + h) ** 2) / ((x + h) ** 2 - 4) # going to right side so increasing
yLeft = (3 * (x - h) ** 2) / ((x - h) ** 2 - 4) # going to right side so decreasing

print("y right = ", yRight)
print("y left = ", yLeft)

if round(yRight) != round(yLeft):
    print("Limit does not exist at x = ", x)
# Out:
# y right =  30002.250018690786
# y left =  -29997.750018749215
# Limit does not exist at x =  2

# %%
x = -2
h = 0.0001

yRight = (3 * (x + h) ** 2) / ((x + h) ** 2 - 4) # going to right side so increasing
yLeft = (3 * (x - h) ** 2) / ((x - h) ** 2 - 4) # going to right side so decreasing

print("y right = ", yRight)
print("y left = ", yLeft)

if round(yRight) != round(yLeft):
    print("Limit does not exist at x = ", x)
# Out:
# y right =  -29997.750018749215
# y left =  30002.250018690786
# Limit does not exist at x =  -2

# %% [markdown]
# # Section 4 : Simple example to compare

# %%
x = 2
h = 0.0001

yRight = 3 * (x + h)  # going to right side so increasing
yLeft = 3 * (x - h)   # going to right side so decreasing

print("y right = ", yRight)
print("y left = ", yLeft)

if round(yRight) != round(yLeft):
    print("Limit does not exist at x = ", x)
else:
    print("Limit at x = ", x, " is ", round(yRight))
# Out:
# y right =  6.000300000000001
# y left =  5.9997
# Limit at x =  2  is  6

# %% [markdown]
# # Section 5 : as x approaches infinity
#
# Example function y = 3*x**2/x**2 - 4

# %%
for xValue in [10, 100, 1000, 10000]:
    limit = (3 * xValue ** 2)/(xValue**2 - 4)
    print("x = ", xValue, " ,Limit = ", limit)
# Out:
# x =  10  ,Limit =  3.125
# x =  100  ,Limit =  3.0012004801920766
# x =  1000  ,Limit =  3.000012000048
# x =  10000  ,Limit =  3.0000001200000046

# %% [markdown]
# # Section 6 : Limits - graphing
#
# Example function : y = 3*x**2/x**2 - 4

# %%
import matplotlib.pyplot as plt
import numpy as np

# for equation y = (3*x**2)/(x**2 - 4)

xValue = 0
yValue = (3*xValue**2)/(xValue**2 - 4)

zoom = 10
xmin = xValue - zoom
xmax = xValue + zoom
ymin = yValue - zoom
ymax = yValue + zoom

x = np.linspace(xmin, xmax, 100)
y = (3*x**2)/(x**2 - 4)

plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot(x, y)
plt.plot([xValue], [yValue], 'ro')

plt.axhline(y = 0, color = 'k')
plt.axvline(x = 0, color = 'k')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Graph of y = (3*xValue**2)/(xValue**2 - 4)")
plt.show()

# %% [markdown]
# # Section 7 : Limits with Sympy
#
# Example function : y = 3*x**2/x**2 - 4

# %%
import sympy
from sympy import symbols

x = symbols('x')

# Put the equation here
eq = (3*x**2)/(x**2 - 4)

# critical values
x1 = 2
x2 = -2

# limit(expression, variable, value)

# first critical point
right = sympy.limit(eq, x, x1, dir='+')
left = sympy.limit(eq, x, x1, dir='-')
print("at x = ", x1)
print("right = ", right)
print("left = ", left)

# second critical point
right = sympy.limit(eq, x, x2, dir='+')
left = sympy.limit(eq, x, x2, dir='-')
print("at x = ", x2)
print("right = ", right)
print("left = ", left)

#infinity
right = sympy.limit(eq, x, sympy.oo)
left = sympy.limit(eq, x, -sympy.oo)
print("as x approaches infinity : ", right)
print("as x approaches negative infinity : ", left)
# Out:
# at x =  2
# right =  oo
# left =  -oo
# at x =  -2
# right =  -oo
# left =  oo
# as x approaches infinity :  3
# as x approaches negative infinity :  3

# %% [markdown]
# # Section 8 : Limits and Slope

# %%
import matplotlib.pyplot as plt
import numpy as np

# for y = x**2

xValue = 1
yValue = xValue**2

# change h value to get better answer
h = 1
yValue2 = (xValue + h)**2

zoom = 10
xmin = xValue - zoom
xmax = xValue + zoom
ymin = yValue - zoom
ymax = yValue + zoom

x = np.linspace(xmin, xmax, 100)
y = x**2

slope = (yValue2 - yValue)/h
print("slope = ", slope)

plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot(x, y)
plt.plot([xValue], [yValue], 'ro')
plt.plot([xValue + h], [yValue2], 'ro')

plt.axhline(y = 0, color = 'k')
plt.axvline(x = 0, color = 'k')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Graph of y = x^2")
plt.show()
# Out:
# slope =  3.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# for y = x**2

xValue = 1
yValue = xValue**2

# change h value to get better answer
h = 0.3
yValue2 = (xValue + h)**2

zoom = 10
xmin = xValue - zoom
xmax = xValue + zoom
ymin = yValue - zoom
ymax = yValue + zoom

x = np.linspace(xmin, xmax, 100)
y = x**2

slope = (yValue2 - yValue)/h
print("slope = ", slope)

plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot(x, y)
plt.plot([xValue], [yValue], 'ro')
plt.plot([xValue + h], [yValue2], 'ro')

plt.axhline(y = 0, color = 'k')
plt.axvline(x = 0, color = 'k')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Graph of y = x^2")
plt.show()
# Out:
# slope =  2.3000000000000007

# %%
# loop but no graph
import matplotlib.pyplot as plt
import numpy as np

xValue = 1
yValue = xValue**2

# smaller h values get better approximations
for a in range(1, 11):
    h = 10**(-a)
    yValue2 = (xValue + h)**2
    slope = (yValue2 - yValue)/h
    print("slope = ", slope)
# Out:
# slope =  2.100000000000002
# slope =  2.0100000000000007
# slope =  2.0009999999996975
# slope =  2.000099999999172
# slope =  2.00001000001393
# slope =  2.0000009999243673
# slope =  2.0000001010878066
# slope =  1.999999987845058
# slope =  2.000000165480742
# slope =  2.000000165480742

# %% [markdown]
# # Section 9 : Limits and Slope - Another example
#
# y = x**3

# %%
import matplotlib.pyplot as plt
import numpy as np

# for y = x**3

xValue = 1
yValue = xValue**3

# change h value to get better answer
h = 1
yValue2 = (xValue + h)**3

zoom = 10
xmin = xValue - zoom
xmax = xValue + zoom
ymin = yValue - zoom
ymax = yValue + zoom

x = np.linspace(xmin, xmax, 100)
y = x**3

slope = (yValue2 - yValue)/h
print("slope = ", slope)

plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot(x, y)
plt.plot([xValue], [yValue], 'ro')
plt.plot([xValue + h], [yValue2], 'ro')

plt.axhline(y = 0, color = 'k')
plt.axvline(x = 0, color = 'k')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Graph of y = x^3")
plt.show()
# Out:
# slope =  7.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# for y = x**3

xValue = 1
yValue = xValue**3

# change h value to get better answer
h = 0.3
yValue2 = (xValue + h)**3

zoom = 10
xmin = xValue - zoom
xmax = xValue + zoom
ymin = yValue - zoom
ymax = yValue + zoom

x = np.linspace(xmin, xmax, 100)
y = x**3

slope = (yValue2 - yValue)/h
print("slope = ", slope)

plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot(x, y)
plt.plot([xValue], [yValue], 'ro')
plt.plot([xValue + h], [yValue2], 'ro')

plt.axhline(y = 0, color = 'k')
plt.axvline(x = 0, color = 'k')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Graph of y = x^3")
plt.show()
# Out:
# slope =  3.99

# %%
# loop but no graph
import matplotlib.pyplot as plt
import numpy as np

xValue = 1
yValue = xValue**3

# smaller h values get better approximations
for a in range(1, 11):
    h = 10**(-a)
    yValue2 = (xValue + h)**3
    slope = (yValue2 - yValue)/h
    print("slope = ", slope)
# Out:
# slope =  3.310000000000004
# slope =  3.0301000000000133
# slope =  3.0030009999997276
# slope =  3.0003000099987354
# slope =  3.000030000110953
# slope =  3.0000029997978572
# slope =  3.000000301511818
# slope =  3.0000000039720476
# slope =  3.000000248221113
# slope =  3.000000248221113
