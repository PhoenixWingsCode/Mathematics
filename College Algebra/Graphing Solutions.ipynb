# %% [markdown]
# # Section 1 : Use numpy library instead of a loop

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10

#Define how many points to plot
points = 10*(xmax-xmin)

#Define the array of x values once
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) #window size
plt.plot([xmin, xmax], [0, 0], 'b') #blue x axis
plt.plot([0,0], [ymin, ymax], 'b') #blue y axis

#Line 1
y1 = 2*x
plt.plot(x, y1)

#Line 2
y2 = x**2 - 3
plt.plot(x, y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10

#Define how many points to plot
points = (xmax-xmin) #Becomes a lot more sharper because it tries to plot every point possible

#Define the array of x values once
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) #window size
plt.plot([xmin, xmax], [0, 0], 'b') #blue x axis
plt.plot([0,0], [ymin, ymax], 'b') #blue y axis

#Line 1
y1 = 2*x
plt.plot(x, y1)

#Line 2
y2 = x**2 - 3
plt.plot(x, y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10

#Define how many points to plot
points = 10*(xmax-xmin) #Becomes a lot more sharper because it tries to plot every point possible

#Define the array of x values once
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) #window size
plt.plot([xmin, xmax], [0, 0], 'b') #blue x axis
plt.plot([0,0], [ymin, ymax], 'b') #blue y axis

#Line 1
y1 = -3*x
plt.plot(x, y1)

#Line 2
y2 = x**3
plt.plot(x, y2)

plt.show()

# %% [markdown]
# # Section 2 : Graph the solution

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10

#Define how many points to plot
points = 2*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) #window size
plt.plot([xmin, xmax], [0, 0], 'b') #blue x axis
plt.plot([0,0], [ymin, ymax], 'b') #blue y axis

#line 1 
y1 = x+6
plt.plot(x, y1)
plt.fill_between(x, y1, ymax, facecolor='red') # fill the x values from y1 to ymax

#line 2
y2 = x+3
plt.plot(x, y2)
plt.fill_between(x, y2, y1, facecolor='yellow')

#line 3
y3 = x-1
plt.plot(x, y3)
plt.fill_between(x, y3, y2, facecolor='green')

#line 4
y4 = x-4
plt.plot(x, y4)
plt.fill_between(x, y4, y3, facecolor='blue')

plt.show()

# %% [markdown]
# # Section 3 : Interactive graphs

# %%
#! pip install ipywidgets
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Define the graphing function
def f(m, b, zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10 * (xmax - xmin)
    x = np.linspace(xmin, xmax, int(points))
    y = m * x + b

    plt.figure(figsize=(6,6))
    plt.axis([xmin, xmax, ymin, ymax])  # window size
    plt.plot([xmin, xmax], [0, 0], 'black')  # black x axis
    plt.plot([0, 0], [ymin, ymax], 'black')  # black y axis
    plt.plot(x, y, label=f"y = {m}x + {b}")
    plt.title('y = mx + b')
    plt.legend()
    plt.grid(True)
    plt.show()

# Set up and display the sliders
interactive_plot = interactive(f, m=(-9, 9), b=(-9, 9), zoom=(1, 100))
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=0, description='m', max=9, min=-9), IntSlider(value=0, description='b', …

# %% [markdown]
# # Section 4 : Graphing weather data
#
# Columns :
# time, tavg(average), tmin(minimum), tmax(maximum), prcp(perspiration), snow, wdir(wind direction), wspd(wind speed), wpgt(wind guts), pres, tsun(sun)

# %%
#! pip install meteostat
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

start = datetime(2022, 1, 1) #year, month, day
end = datetime(2022, 7, 31)

#Create Point for Vancouver, BC or Philadelphia, PA
#vancouver = Point(49.2497, -123.1193, 70)
#Point(latitude, longitude)
philly = Point(39.97, -75.13, 25)

#Get daily data for 2018
data = Daily(philly, start, end)
data = data.fetch()

#Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()

# %%
#! pip install meteostat
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

start = datetime(2022, 1, 1) #year, month, day
end = datetime(2022, 7, 31)

#Create Point for Vancouver, BC or Philadelphia, PA
#vancouver = Point(49.2497, -123.1193, 70)
#Point(latitude, longitude)
philly = Point(39.97, -75.13, 25)

#Get daily data for 2018
data = Daily(philly, start, end)
data = data.fetch()

#Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'prcp'])
plt.show()

# %%
#! pip install meteostat
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

start = datetime(2022, 1, 1) #year, month, day
end = datetime(2022, 7, 31)

#Create Point for Vancouver, BC or Philadelphia, PA
#vancouver = Point(49.2497, -123.1193, 70)
#Point(latitude, longitude)
philly = Point(39.97, -75.13, 25)

#Get daily data for 2018
data = Daily(philly, start, end)
data = data.fetch()

#Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'prcp', 'snow'])
plt.show()
