# %% [markdown]
# # Section 1 : Selling tee shirts example

# %%
price = 5
demand = 50 - 2*price
revenue = price*demand
total_cost = 4*demand
profit = revenue - total_cost

print("price: ", price)
print("demand: ", demand)
print("revenue: ", revenue)
print("total_cost: ", total_cost)
print("profit: ", profit)
# Out:
# price:  5
# demand:  40
# revenue:  200
# total_cost:  160
# profit:  40

# %% [markdown]
# # Section 2 : Graph the solution

# %%
import matplotlib.pyplot as plt
import numpy as np

# price = x
# demand = y

price1 = 2
demand1 = 46
price2 = 10
demand2 = 30

m = (demand2 -  demand1)/(price2 - price1)
b = demand1 - m*price1

#This becomes a y=mx+b equation

xmin = 0
xmax = 50
ymin = 0
ymax = 320
points = 10*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0,0], 'b')
plt.plot([0, 0], [ymin, ymax], 'b')

plt.xlabel("Price")
plt.title("Financial Algebra")

#Line 1
demand = m*x + b
plt.ylabel("Demand")
plt.plot(x, demand)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# price = x
# demand = y

price1 = 2
demand1 = 46
price2 = 10
demand2 = 30

m = (demand2 -  demand1)/(price2 - price1)
b = demand1 - m*price1

#This becomes a y=mx+b equation

xmin = 0
xmax = 50
ymin = 0
ymax = 320
points = 10*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0,0], 'b')
plt.plot([0, 0], [ymin, ymax], 'b')

plt.xlabel("Price")
plt.title("Financial Algebra")

#Line 1
demand = m*x + b
plt.ylabel("Demand")
plt.plot(x, demand)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# price = x
# demand = y

price1 = 2
demand1 = 46
price2 = 10
demand2 = 30

m = (demand2 -  demand1)/(price2 - price1)
b = demand1 - m*price1

#This becomes a y=mx+b equation

xmin = 0
xmax = 50
ymin = 0
ymax = 320
points = 10*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0,0], 'b')
plt.plot([0, 0], [ymin, ymax], 'b')

plt.xlabel("Price")
plt.title("Financial Algebra")

#Line 1
#demand = m*x + b
#plt.ylabel("Demand")
#plt.plot(x, demand)

#Line 2
revenue = x*demand
plt.plot(x, revenue)
plt.ylabel("Revenue")

plt.show()

# %% [markdown]
# # Section 3 : Supply and Demand Graph
#
# Marginal cost, revenue, profit is the result when making and selling one more product

# %%
import matplotlib.pyplot as plt

oldDemandx = 1
newDemandx = 12
oldPricey = 14
newPricey = 3
oldSupplyx = 11
newSupplyx = 1

#For the graph
xmin = 0
xmax = 15
ymin = 0
ymax = 15

#Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [0,0], 'b')
plt.plot([0, 0], [ymin, ymax], 'b')
plt.xlabel("Quantity")
plt.ylabel("Price")
plt.title("Green=Supply, Red=Demand")

#Plot the demand function as a red line
plt.plot([oldDemandx, newDemandx], [oldPricey, newPricey], 'r')

#Plot the supply function as a green line
plt.plot([oldSupplyx, newSupplyx], [oldPricey, newPricey], 'g')

plt.show()

# %% [markdown]
# # Section 4 : Calculate the price elasticity of demand
#
# percentage change in demand / percentage change in price

# %%
oldDemand = 5
newDemand = 6
oldPrice = 11
newPrice = 10

#percent change in price
priceChange = (newPrice - oldPrice) / oldPrice

#percent change in demand
demandChange = (newDemand - oldDemand) / oldDemand

elasticityNumber = demandChange/priceChange

#Elasticity
print(elasticityNumber)

if elasticityNumber>1:
    print("Demand is elastic")
elif elasticityNumber==1:
    print("Demand is unitary or proportional")
elif elasticityNumber<1:
    print("Demand is inelastic")
else:
    print("?")
# Out:
# -2.2
# Demand is inelastic

# %% [markdown]
# # Section 4 : Calculate the price elasticity of demand
#
# percentage change in supply / percentage change in price

# %%
oldPrice = 4
newPrice = 7
oldSupply = 10
newSupply = 11

#Percent change in price
priceChange = (newPrice - oldPrice) / oldPrice

#Percent change in supply
supplyChange = (newSupply - oldSupply) / oldSupply

elasticityNumber = supplyChange/priceChange

#Elasticity
print(elasticityNumber)

if elasticityNumber>1:
    print("Supply is elastic")
elif elasticityNumber==1:
    print("Supply is unitary or proportional")
elif elasticityNumber<1:
    print("Supply is inelastic")
else:
    print("?")
# Out:
# 0.13333333333333333
# Supply is inelastic
